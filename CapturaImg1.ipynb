# %%
import cv2 # opencv
import numpy as np
import matplotlib.pyplot as plt
#cargar imagen
path="........"
imagen=cv2.imread('imagenPNG.png')
plt.show('imagen')
plt.title("importar imagen")
plt.show()
